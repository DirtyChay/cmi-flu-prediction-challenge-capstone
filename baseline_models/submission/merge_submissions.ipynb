# %% [markdown]
# # Merge Baseline Submissions
# Finds all individual task CSVs (`task_4_1.csv` … `task_4_6.csv`) in the current folder and merges them into a single `final_submission.csv`.
# Tasks 4.7–4.10 are not produced by the baseline notebooks and are filled with 0.

# %%
import glob
import re
from functools import reduce

import pandas as pd

# %%
# Find all task CSVs in the current (submission) directory
csv_files = glob.glob('task_*.csv')
print(f"Found {len(csv_files)} files to merge: {sorted(csv_files)}\n")

if csv_files:
    # Read each CSV and merge on Participant_ID (outer join handles any missing participants)
    dfs = [pd.read_csv(f) for f in csv_files]
    final_df = reduce(lambda left, right: pd.merge(left, right, on='Participant_ID', how='outer'), dfs)

    # Tasks 4.7-4.10 are not produced by baseline notebooks — fill with 0
    for col in ['Task_4.7', 'Task_4.8', 'Task_4.9', 'Task_4.10']:
        final_df[col] = 0


    # Sort columns: Participant_ID first, then numerically by task number
    def sort_cols(col_name):
        if col_name == 'Participant_ID':
            return -1
        match = re.search(r'4[._](\d+)', col_name)
        return int(match.group(1)) if match else 999


    final_df = final_df[sorted(final_df.columns, key=sort_cols)]

    final_df.to_csv('final_submission.csv', index=False)
    print("Saved to 'final_submission.csv'")
    display(final_df)
else:
    print("No 'task_*.csv' files found in the current directory.")
# Out:
# Found 6 files to merge: ['task_4_1.csv', 'task_4_2.csv', 'task_4_3.csv', 'task_4_4.csv', 'task_4_5.csv', 'task_4_6.csv']
#
# Saved to 'final_submission.csv'
#      Participant_ID   Task_4.1     Task_4.2    Task_4.3   Task_4.4*  \
# 0   2024_UGA.ID_077   6.536243    76.568101   46.815201   33.665440
# 1   2024_UGA.ID_086  21.378141    22.023497   65.684473   52.971010
# 2   2024_UGA.ID_128  37.247343   405.496048   22.823225   24.093793
# 3   2024_UGA.ID_170   6.434223   103.159883   26.410192   22.055204
# 4   2024_UGA.ID_179   6.639880    46.549061   82.985505   51.387502
# 5   2024_UGA.ID_215   6.832936   374.459505   40.545315   27.905984
# 6   2024_UGA.ID_219   6.722223    44.734713   57.449192   37.400778
# 7   2024_UGA.ID_275  10.801796    33.342611   47.225891   37.908066
# 8   2024_UGA.ID_295  20.404980    30.624336  827.429580  346.167522
# 9   2024_UGA.ID_296   6.532295    22.416691   37.257882   29.197558
# 10  2024_UGA.ID_306  12.059251    50.506995  146.780807   85.646271
# 11  2024_UGA.ID_313  11.587181    63.393081   37.217226   31.978731
# 12  2024_UGA.ID_321   6.217489    24.048912   13.016771   12.275709
# 13  2024_UGA.ID_335   6.536243   164.001898   46.815201   33.665440
# 14  2024_UGA.ID_340  33.871978   114.898692   58.079852   51.145238
# 15  2024_UGA.ID_352  18.072422    76.995626   58.589361   47.714374
# 16  2024_UGA.ID_353   6.280376   119.610467   37.461827   29.650453
# 17  2024_UGA.ID_368   6.333796    18.666122   26.467923   22.191415
# 18  2024_UGA.ID_404   6.316072    60.710168   72.819203   44.199167
# 19  2024_UGA.ID_411  12.018242    43.942566   18.163866   17.312672
# 20  2024_UGA.ID_412  19.257814   124.591742   41.080013   34.949759
# 21  2024_UGA.ID_430  24.575583    73.817243   39.712907   31.768625
