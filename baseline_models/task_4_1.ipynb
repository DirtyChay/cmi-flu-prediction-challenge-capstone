# %%
import os

USE_GOOGLE_COLAB = False

if USE_GOOGLE_COLAB:
    from google.colab import drive

    drive.mount('/content/drive')
    DATA_PATH = os.path.join(os.getcwd(), 'drive', 'MyDrive', 'DSE_260A', 'data', 'cleaned_data')
else:
    DATA_PATH = '../cleaned_data'

# %% [markdown]
# # Task 4.1
#
# **4.1 predict magnitude of antibody response - H1N1 A/Victoria/4897/2022 (D28)**
# * Training Data: Demographics + Day 0 + Day 7 innate
# * Assay: HAI
# * Measure: Single strain titer
# * Metric: Spearman correlation
# * Full description: HAI titer for H1N1 A/Victoria/4897/2022 at Day 28

# %%
TARGET_COL = 'HAI_H1N1 A/Victoria/4897/2022_d28'  # task 4.1

# %% [markdown]
# ## Task 4.1: BASELINE LINNEAR REGRESSION MODEL
# Magnitude refers to the strength of the antibody response against a single specific vaccine strain.
# We are predicting the HAI titer for H1N1 A/Victoria/4897/2022 at Day 28 post-vaccination.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import spearmanr
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_predict, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
train_participants = pd.read_csv(DATA_PATH + '/participants_cleaned.csv')
train_hai = pd.read_csv(DATA_PATH + '/hai_cleaned.csv')

train_hai = train_hai[['participant_id'] + ['HAI_H1N1 A/Victoria/4897/2022_d0'] + [TARGET_COL]]

# %%
for name, df in {'train_hai': train_hai, 'train_participants': train_participants}.items():
    print(f"\n{'=' * 50}")
    print(f'TABLE: {name}')
    print(f"{'=' * 50}")
    display(df.head(5))
# Out:
# ==================================================
# TABLE: train_hai
# ==================================================
#     participant_id  HAI_H1N1 A/Victoria/4897/2022_d0  \
# 0  2016_UGA.ID_001                               NaN
# 1  2016_UGA.ID_002                               NaN
# 2  2016_UGA.ID_003                               NaN
# 3  2016_UGA.ID_004                               NaN
# 4  2016_UGA.ID_005                               NaN
#
#    HAI_H1N1 A/Victoria/4897/2022_d28
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ==================================================
# TABLE: train_participants
# ==================================================
#      participant_id PART_biological_sex PART_arm_name  PART_age
# 0  SDY269.SUB112836              female         Other      28.0
# 1  SDY269.SUB112849              female         Other      39.0
# 2  SDY269.SUB112854                male         Other      46.0
# 3  SDY269.SUB112860              female         Other      32.0
# 4  SDY269.SUB112881              female         Other      29.0

# %% [markdown]
# ### Data is pre-cleaned
# Both tables are already one row per participant with cleaned column names:
# - HAI columns follow `HAI_{strain}_d{timepoint}` format
# - Participant columns follow `PART_{field}` format
#
# We just need to merge them and separate features from target.

# %%
# Merge HAI and participant tables
data = train_hai.merge(train_participants, on='participant_id', how='inner')
print(f'Merged shape: {data.shape}')
data.head()
# Out:
# Merged shape: (3757, 6)
#     participant_id  HAI_H1N1 A/Victoria/4897/2022_d0  \
# 0  2016_UGA.ID_001                               NaN
# 1  2016_UGA.ID_002                               NaN
# 2  2016_UGA.ID_003                               NaN
# 3  2016_UGA.ID_004                               NaN
# 4  2016_UGA.ID_005                               NaN
#
#    HAI_H1N1 A/Victoria/4897/2022_d28 PART_biological_sex     PART_arm_name  \
# 0                                NaN              female  Standard Fluzone
# 1                                NaN              female  Standard Fluzone
# 2                                NaN              female  Standard Fluzone
# 3                                NaN                male  Standard Fluzone
# 4                                NaN              female  Standard Fluzone
#
#    PART_age
# 0      29.0
# 1      29.0
# 2      28.0
# 3      27.0
# 4      25.0

# %%
# Features: only d0 HAI columns + participant columns (no future data)
feature_cols = [c for c in data.columns
                if c != 'participant_id'
                and c != TARGET_COL
                and not c.endswith('_d28')
                and not c.endswith('_d365')]

print(f'Target: {TARGET_COL}')
print(f'Features: {len(feature_cols)}')
print(f'Sample feature names: {feature_cols[:5]}')
# Out:
# Target: HAI_H1N1 A/Victoria/4897/2022_d28
# Features: 4
# Sample feature names: ['HAI_H1N1 A/Victoria/4897/2022_d0', 'PART_biological_sex', 'PART_arm_name', 'PART_age']

# %% [markdown]
# ### Build X and y

# %%
# Target: single strain HAI titer at Day 28
y_vals = data[TARGET_COL].copy()

# Drop rows where target is NaN
mask = y_vals.notna()
y_vals = y_vals[mask]
X = data.loc[mask, feature_cols].copy()

print(f'Samples: {len(X)}')
print(f'Features: {X.shape[1]}')
# Out:
# Samples: 212
# Features: 4

# %% [markdown]
# ### Encode categorical features

# %%
# One-hot encode any categorical PART_ columns
cat_cols = X.select_dtypes(include='object').columns.tolist()
if cat_cols:
    print(f'Encoding categorical columns: {cat_cols}')
    X = pd.get_dummies(X, columns=cat_cols, drop_first=True)
print(f'Final feature count: {X.shape[1]}')
# Out:
# Encoding categorical columns: ['PART_biological_sex', 'PART_arm_name']
# Final feature count: 4
# /var/folders/kp/4mhl7j_j6354gqcs12nt1y680000gn/T/ipykernel_24033/398821456.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = X.select_dtypes(include='object').columns.tolist()

# %%
#Drop any columns with more than 40% null values and print all dropped columns
def drop_null_columns(df, threshold=0.4):
    null_counts = df.isnull().sum()
    total_rows = len(df)
    null_percentages = null_counts / total_rows
    columns_to_drop = null_percentages[null_percentages > threshold].index
    df = df.drop(columns=columns_to_drop)
    print(f"Dropped columns with more than {threshold * 100}% null values:")
    print(columns_to_drop)


drop_null_columns(X)
# Out:
# Dropped columns with more than 40.0% null values:
# Index([], dtype='str')

# %%
X.head()
# Out:
#       HAI_H1N1 A/Victoria/4897/2022_d0  PART_age  PART_biological_sex_male  \
# 1544                          2.321928      46.0                      True
# 1545                          2.321928      68.0                     False
# 1546                          2.321928      28.0                     False
# 1547                          2.321928      63.0                     False
# 1548                          2.321928      30.0                     False
#
#       PART_arm_name_Standard Fluzone
# 1544                            True
# 1545                           False
# 1546                            True
# 1547                            True
# 1548                            True

# %%
#Standard scale PART_age
scaler = StandardScaler()
X['PART_age'] = scaler.fit_transform(X[['PART_age']])
X.head()
# Out:
#       HAI_H1N1 A/Victoria/4897/2022_d0  PART_age  PART_biological_sex_male  \
# 1544                          2.321928 -0.487221                      True
# 1545                          2.321928  0.747778                     False
# 1546                          2.321928 -1.497674                     False
# 1547                          2.321928  0.467096                     False
# 1548                          2.321928 -1.385401                     False
#
#       PART_arm_name_Standard Fluzone
# 1544                            True
# 1545                           False
# 1546                            True
# 1547                            True
# 1548                            True

# %%
# X and y are ready — proceed to training

# %% [markdown]
# ### Train model
#
# **Why Spearman correlation?**
#
# This task uses Spearman correlation as its evaluation metric. Spearman only cares about
# **rankings**. It converts all your true values and predictions into ranks (1st, 2nd, 3rd…)
# and then checks whether those two rank orderings agree.
#
# This is a good fit for antibody data because:
# - HAI titers are noisy and vary across studies, so predicting exact values is unrealistic.
# - What matters clinically is *relative* response: can we identify who will respond well vs. poorly?
# - Spearman is also robust to outliers and non-linear relationships — if your predictions are
#   monotonically related to the truth (always going in the right direction), Spearman rewards that
#   even if the relationship isn't a straight line.
#
# **Interpreting the score:**
# A Spearman of 1.0 means perfect ranking agreement, 0.0 means no relationship, and -1.0 means
# perfectly reversed rankings.

# %%
# Simple pipeline: impute remaining NaNs, then regress
model = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('regressor', LinearRegression())
])

# --- Cross-validated evaluation (the real score) ---
cv = KFold(n_splits=5, shuffle=True, random_state=42)
y_pred_cv = cross_val_predict(model, X, y_vals, cv=cv)
rho_cv, pval_cv = spearmanr(y_vals, y_pred_cv)
print(f'Spearman (5-fold CV): {rho_cv:.3f}  (p-value: {pval_cv:.4f})')
# Out:
# Spearman (5-fold CV): 0.339  (p-value: 0.0000)

# %% [markdown]
# ### Why Cross-Validation?
#
# The CV score above is our real evaluation. Each participant's prediction was made by a model
# that **never saw that participant during training** (5-fold: train on 4/5 of the data, predict
# the held-out 1/5, rotate). This tells us how the model would perform on new, unseen participants.
#
# The train score is shown only as an overfitting diagnostic — a large gap between train and CV
# means the model memorised noise rather than learning real patterns.

# %%
plt.figure(figsize=(6, 5))
plt.scatter(y_vals, y_pred_cv, alpha=0.5, color='teal')
plt.plot([y_vals.min(), y_vals.max()], [y_vals.min(), y_vals.max()], 'r--', label='Perfect')
plt.xlabel('True log(HAI) at D28')
plt.ylabel('Predicted (held-out)')
plt.title(f'Task 4.1 — Linear Model (5-Fold CV)\nSpearman ρ = {rho_cv:.3f}')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Next Steps
#
# Use the linnear reg model to predict challenge set

# %%
challenge_participants = pd.read_csv(DATA_PATH + '/challenge_participants_cleaned.csv')
challenge_hai = pd.read_csv(DATA_PATH + '/challenge_hai_cleaned.csv')

challenge_hai = challenge_hai[['participant_id'] + ['HAI_H1N1 A/Victoria/4897/2022_d0']]
test_data = challenge_hai.merge(challenge_participants, on='participant_id', how='inner')
print(f'Merged shape: {test_data.shape}')
test_data.head()

test_data.set_index('participant_id', inplace=True)
# Out:
# Merged shape: (40, 5)

# %%
cat_cols = test_data.select_dtypes(include='object').columns.tolist()
if cat_cols:
    print(f'Encoding categorical columns: {cat_cols}')
    test_data = pd.get_dummies(test_data, columns=cat_cols, drop_first=True)
print(f'Final feature count: {test_data.shape[1]}')
# Out:
# Encoding categorical columns: ['PART_biological_sex', 'PART_arm_name']
# Final feature count: 4
# /var/folders/kp/4mhl7j_j6354gqcs12nt1y680000gn/T/ipykernel_24033/3870543911.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = test_data.select_dtypes(include='object').columns.tolist()

# %%
test_data['PART_age'] = scaler.transform(test_data[['PART_age']])
test_data
# Out:
#                  HAI_H1N1 A/Victoria/4897/2022_d0  PART_age  \
# participant_id
# 2024_UGA.ID_077                          2.321928  0.972323
# 2024_UGA.ID_086                          4.321928  0.579369
# 2024_UGA.ID_128                          5.321928 -0.655629
# 2024_UGA.ID_170                          2.321928  1.084595
# 2024_UGA.ID_179                          2.321928  0.860050
# 2024_UGA.ID_215                          2.321928 -0.655629
# 2024_UGA.ID_219                          2.321928 -0.543357
# 2024_UGA.ID_275                          3.321928  1.421413
# 2024_UGA.ID_295                          4.321928  0.916187
# 2024_UGA.ID_296                          2.321928  0.972323
# 2024_UGA.ID_306                          3.321928  0.635505
# 2024_UGA.ID_313                          3.321928  0.916187
# 2024_UGA.ID_321                          2.321928  0.018006
# 2024_UGA.ID_335                          2.321928  0.972323
# 2024_UGA.ID_340                          5.321928  0.018006
# 2024_UGA.ID_352                          4.321928  0.467096
# 2024_UGA.ID_353                          2.321928  1.253004
# 2024_UGA.ID_368                          2.321928  1.196868
# 2024_UGA.ID_404                          2.321928 -0.094267
# 2024_UGA.ID_411                          3.321928 -0.655629
# 2024_UGA.ID_412                          4.321928  0.018006
# 2024_UGA.ID_430                          4.321928 -1.722219
# 2024_UGA.ID_432                          2.321928  0.298687
# 2024_UGA.ID_438                          2.321928 -0.711766
# 2024_UGA.ID_443                          3.321928 -1.104720
# 2024_UGA.ID_448                          2.321928 -0.038130
# 2024_UGA.ID_455                          4.321928  1.926640
# 2024_UGA.ID_461                          6.321928 -0.599493
# 2024_UGA.ID_507                          3.321928 -1.553810
# 2024_UGA.ID_512                          5.321928 -1.329265
# 2024_UGA.ID_572                          4.321928 -0.543357
# 2024_UGA.ID_586                          2.321928  0.691641
# 2024_UGA.ID_589                          2.321928  0.860050
# 2024_UGA.ID_594                          4.321928  1.253004
# 2024_UGA.ID_600                          2.321928  0.410960
# 2024_UGA.ID_614                          2.321928  1.814367
# 2024_UGA.ID_629                          2.321928  0.579369
# 2024_UGA.ID_632                          4.321928  0.860050
# 2024_UGA.ID_649                          2.321928  1.196868
# 2024_UGA.ID_683                          5.321928 -2.002900
#
#                  PART_biological_sex_male  PART_arm_name_Standard Fluzone
# participant_id
# 2024_UGA.ID_077                     False                           False
# 2024_UGA.ID_086                      True                           False
# 2024_UGA.ID_128                     False                            True
# 2024_UGA.ID_170                     False                           False
# 2024_UGA.ID_179                     False                           False
# 2024_UGA.ID_215                     False                            True
# 2024_UGA.ID_219                      True                            True
# 2024_UGA.ID_275                     False                           False
# 2024_UGA.ID_295                     False                           False
# 2024_UGA.ID_296                      True                           False
# 2024_UGA.ID_306                     False                           False
# 2024_UGA.ID_313                      True                           False
# 2024_UGA.ID_321                     False                            True
# 2024_UGA.ID_335                     False                           False
# 2024_UGA.ID_340                      True                            True
# 2024_UGA.ID_352                      True                            True
# 2024_UGA.ID_353                      True                           False
# 2024_UGA.ID_368                     False                           False
# 2024_UGA.ID_404                     False                            True
# 2024_UGA.ID_411                      True                            True
# 2024_UGA.ID_412                     False                            True
# 2024_UGA.ID_430                     False                            True
# 2024_UGA.ID_432                      True                            True
# 2024_UGA.ID_438                      True                            True
# 2024_UGA.ID_443                     False                            True
# 2024_UGA.ID_448                      True                            True
# 2024_UGA.ID_455                     False                           False
# 2024_UGA.ID_461                      True                            True
# 2024_UGA.ID_507                     False                            True
# 2024_UGA.ID_512                     False                            True
# 2024_UGA.ID_572                     False                            True
# 2024_UGA.ID_586                      True                           False
# 2024_UGA.ID_589                     False                           False
# 2024_UGA.ID_594                      True                           False
# 2024_UGA.ID_600                      True                            True
# 2024_UGA.ID_614                     False                           False
# 2024_UGA.ID_629                     False                           False
# 2024_UGA.ID_632                     False                           False
# 2024_UGA.ID_649                      True                           False
# 2024_UGA.ID_683                      True                            True

# %%
model.fit(X, y_vals)
y_pred_challenge = model.predict(test_data)
predictions_df = pd.DataFrame({'participant_id': test_data.index, 'predicted_d28_hai': y_pred_challenge})
display(predictions_df.head())
# Out:
#     participant_id  predicted_d28_hai
# 0  2024_UGA.ID_077           2.708462
# 1  2024_UGA.ID_086           4.418064
# 2  2024_UGA.ID_128           5.219066
# 3  2024_UGA.ID_170           2.685766
# 4  2024_UGA.ID_179           2.731157

# %%
# Inverse transform the predicted_d28_hai values from log2 scale
predictions_df['predicted_d28_hai_original_scale'] = np.exp2(predictions_df['predicted_d28_hai'])

# Display the updated DataFrame with the inverse transformed values
display(predictions_df.head())
# Out:
#     participant_id  predicted_d28_hai  predicted_d28_hai_original_scale
# 0  2024_UGA.ID_077           2.708462                          6.536243
# 1  2024_UGA.ID_086           4.418064                         21.378141
# 2  2024_UGA.ID_128           5.219066                         37.247343
# 3  2024_UGA.ID_170           2.685766                          6.434223
# 4  2024_UGA.ID_179           2.731157                          6.639880

# %%
plt.figure(figsize=(15, 7))

# Get the HAI D0 values from test_data (ensure index is aligned if not already)
d0_hai_values = test_data['HAI_H1N1 A/Victoria/4897/2022_d0']

# Plot predicted D28 HAI values
plt.scatter(predictions_df['participant_id'], predictions_df['predicted_d28_hai'], color='red',
            label='Predicted D28 HAI', alpha=0.7)

# Plot Day 0 HAI values. Ensure the order of participant_id is the same as in predictions_df for correct alignment
# If predictions_df was created from test_data.index, they should be aligned.
plt.scatter(predictions_df['participant_id'], d0_hai_values.loc[predictions_df['participant_id']], color='blue',
            label='Day 0 HAI', alpha=0.7)

plt.xlabel('Participant ID')
plt.ylabel('HAI Value')
plt.title('Predicted D28 HAI vs. Day 0 HAI for Test Set Participants')
plt.xticks(rotation=90, fontsize=8)  # Rotate x-axis labels for readability
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
predictions_df.drop(columns=['predicted_d28_hai'], inplace=True)
predictions_df.rename(columns={'predicted_d28_hai_original_scale': 'Task_4.1', 'participant_id': 'Participant_ID'},
                      inplace=True)
os.makedirs('submission', exist_ok=True)
predictions_df.to_csv('submission/task_4_1.csv', index=False)
