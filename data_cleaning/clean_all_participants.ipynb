# %% [markdown]
# # Participants Data Cleaning — Training + Challenge
#
# **Cleans and standardizes participant demographic data for both the training and challenge sets.**
# - Input: `train_participants.tsv`, `challenge_participants.tsv`
# - Output: `participants_cleaned.csv`, `challenge_participants_cleaned.csv`

# %% [markdown]
# ## Design notes
#
# **Columns selected:** `biological_sex`, `min_age`, `max_age`, `arm_name`. Race and geolocation are omitted — in the challenge set all participants share the same values (`race: unknown`, `US: Georgia`), so these features carry no signal.
#
# **Age:** Computed as `(min_age + max_age) / 2`; min and max are identical for most participants.
#
# **Arm simplification:** Arm names are mapped to `High Dose Fluzone`, `Standard Fluzone`, or `Other` to normalize across cohort naming conventions.
#
# **Column prefix:** All feature columns are prefixed with `PART_` to distinguish participant demographics from other data types.

# %%
COLUMNS_TO_KEEP = ['participant_id', 'biological_sex', 'min_age', 'max_age', 'arm_name']

# %%
DATA_PATH = '../data'
CLEAN_DATA_PATH = '../cleaned_data'

# %%
import os

import pandas as pd

# %%
def simplify_arm(arm):
    if isinstance(arm, str):
        if 'High Dose' in arm:
            return 'High Dose Fluzone'
        elif 'Standard' in arm or 'standard' in arm:
            return 'Standard Fluzone'
    return 'Other'

# %% [markdown]
# ## Training Data

# %%
df_train = pd.read_csv(DATA_PATH + '/train_participants.tsv', sep='\t')
print(f'Raw shape: {df_train.shape}')
df_train.head()

# %% [markdown]
# ### Select relevant columns

# %%
df_train = df_train[COLUMNS_TO_KEEP]
print(f'After column selection: {df_train.shape}')
df_train.head()

# %% [markdown]
# ### Feature engineering and cleaning

# %%
df_train['age'] = (df_train['min_age'] + df_train['max_age']) / 2
df_train = df_train.drop(columns=['min_age', 'max_age'])
df_train['biological_sex'] = df_train['biological_sex'].str.lower()
df_train['arm_name'] = df_train['arm_name'].apply(simplify_arm)
print(f'After feature engineering: {df_train.shape}')
df_train.head()

# %% [markdown]
# ### Verify cleaning

# %%
for col in df_train.columns:
    print(f'{col}: {df_train[col].unique()}\n')

# %% [markdown]
# ### Rename with PART_ prefix

# %%
df_train.columns = ['participant_id'] + [f'PART_{c}' for c in df_train.columns[1:]]
df_train.head()

# %%
os.makedirs(CLEAN_DATA_PATH, exist_ok=True)
df_train.to_csv(CLEAN_DATA_PATH + '/participants_cleaned.csv', index=False)
print(f'Saved to {CLEAN_DATA_PATH}/participants_cleaned.csv')

# %% [markdown]
# ## Challenge Data

# %%
df_chal = pd.read_csv(DATA_PATH + '/challenge_participants.tsv', sep='\t')
print(f'Raw shape: {df_chal.shape}')
df_chal.head()

# %% [markdown]
# ### Exploratory analysis

# %%
print(df_chal['arm_id'].value_counts().to_string(), '\n')
print(df_chal['geolocation'].value_counts().to_string(), '\n')
print(df_chal['race'].value_counts().to_string(), '\n')
print(df_chal['biological_sex'].value_counts().to_string())

# %% [markdown]
# ### Select relevant columns

# %%
df_chal = df_chal[COLUMNS_TO_KEEP]
print(f'After column selection: {df_chal.shape}')
df_chal.head()

# %% [markdown]
# ### Feature engineering and cleaning

# %%
df_chal['age'] = (df_chal['min_age'] + df_chal['max_age']) / 2
df_chal = df_chal.drop(columns=['min_age', 'max_age'])
df_chal['biological_sex'] = df_chal['biological_sex'].str.lower()
df_chal['arm_name'] = df_chal['arm_name'].apply(simplify_arm)
print(f'After feature engineering: {df_chal.shape}')
df_chal.head()

# %% [markdown]
# ### Verify cleaning

# %%
for col in df_chal.columns:
    print(f'{col}: {df_chal[col].unique()}\n')

# %% [markdown]
# ### Rename with PART_ prefix

# %%
df_chal.columns = ['participant_id'] + [f'PART_{c}' for c in df_chal.columns[1:]]
df_chal.head()

# %%
os.makedirs(CLEAN_DATA_PATH, exist_ok=True)
df_chal.to_csv(CLEAN_DATA_PATH + '/challenge_participants_cleaned.csv', index=False)
print(f'Saved to {CLEAN_DATA_PATH}/challenge_participants_cleaned.csv')
