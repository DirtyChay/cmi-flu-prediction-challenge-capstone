# %%
import os
import numpy as np
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('../data/train_hai.tsv', sep='\t')
df = df.drop(columns=['hai_id', 'material'])
df['value'] = pd.to_numeric(df['value'], errors='coerce')
df = df[df['timepoint'].isin([0.0, 28.0, 365.0])]
df.head()
# Out:
#     participant_id  timepoint                  virus_strain  value
# 0  2016_UGA.ID_001        0.0  H1N1 A/South Carolina/1/1918   20.0
# 1  2016_UGA.ID_001       28.0  H1N1 A/South Carolina/1/1918   40.0
# 2  2016_UGA.ID_002        0.0  H1N1 A/South Carolina/1/1918    5.0
# 3  2016_UGA.ID_002       28.0  H1N1 A/South Carolina/1/1918    5.0
# 4  2016_UGA.ID_003        0.0  H1N1 A/South Carolina/1/1918   80.0

# %%
df['hai_timepoint'] = 'HAI_' + df['virus_strain'].astype(str) + '_d' + df['timepoint'].astype(int).astype(str)

# Pivot the table
df_pivot = df.pivot_table(
    index='participant_id',
    columns='hai_timepoint',
    values='value'
)

# Reset index to make participant_id a regular column
df_pivot = df_pivot.reset_index()
df_pivot = df_pivot.rename_axis(None, axis=1)
df_pivot.drop(columns=["HAI_-_d0", "HAI_-_d28"], inplace=True)
for col in df_pivot.columns:
    if col != 'participant_id':
        df_pivot[col] = df_pivot[col].apply(lambda x: np.log2(x) if pd.notna(x) else x)

df_pivot
# Out:
#         participant_id  HAI_Anc B/Lee/1940_d0  HAI_Anc B/Lee/1940_d28  \
# 0      2016_UGA.ID_001                    NaN                     NaN
# 1      2016_UGA.ID_002                    NaN                     NaN
# 2      2016_UGA.ID_003                    NaN                     NaN
# 3      2016_UGA.ID_004                    NaN                     NaN
# 4      2016_UGA.ID_005                    NaN                     NaN
# ...                ...                    ...                     ...
# 3752  SDY887.SUB134259                    NaN                     NaN
# 3753  SDY887.SUB134260                    NaN                     NaN
# 3754  SDY887.SUB197783                    NaN                     NaN
# 3755  SDY887.SUB197784                    NaN                     NaN
# 3756  SDY887.SUB197785                    NaN                     NaN
#
#       HAI_Anc B/Lee/1940_d365  HAI_Anc B/Maryland/1959_d0  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# ...                       ...                         ...
# 3752                      NaN                         NaN
# 3753                      NaN                         NaN
# 3754                      NaN                         NaN
# 3755                      NaN                         NaN
# 3756                      NaN                         NaN
#
#       HAI_Anc B/Maryland/1959_d28  HAI_Anc B/Singapore/1964_d0  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 3752                          NaN                          NaN
# 3753                          NaN                          NaN
# 3754                          NaN                          NaN
# 3755                          NaN                          NaN
# 3756                          NaN                          NaN
#
#       HAI_Anc B/Singapore/1964_d28  HAI_H1N1 A/Beijing/262/1995_d0  \
# 0                              NaN                        5.321928
# 1                              NaN                        6.321928
# 2                              NaN                        6.321928
# 3                              NaN                        3.321928
# 4                              NaN                        3.321928
# ...                            ...                             ...
# 3752                           NaN                             NaN
# 3753                           NaN                             NaN
# 3754                           NaN                             NaN
# 3755                           NaN                             NaN
# 3756                           NaN                             NaN
#
#       HAI_H1N1 A/Beijing/262/1995_d28  ...  HAI_Yam B/Sichuan/379/1999_d365  \
# 0                            5.321928  ...                              NaN
# 1                            5.321928  ...                              NaN
# 2                            5.321928  ...                              NaN
# 3                            5.321928  ...                              NaN
# 4                            2.321928  ...                         6.321928
# ...                               ...  ...                              ...
# 3752                              NaN  ...                              NaN
# 3753                              NaN  ...                              NaN
# 3754                              NaN  ...                              NaN
# 3755                              NaN  ...                              NaN
# 3756                              NaN  ...                              NaN
#
#       HAI_Yam B/Texas/6/2011_d0  HAI_Yam B/Texas/6/2011_d28  \
# 0                      7.321928                    8.321928
# 1                      5.321928                    6.321928
# 2                      8.321928                    8.321928
# 3                      4.321928                    6.321928
# 4                      6.321928                    6.321928
# ...                         ...                         ...
# 3752                        NaN                         NaN
# 3753                        NaN                         NaN
# 3754                        NaN                         NaN
# 3755                        NaN                         NaN
# 3756                        NaN                         NaN
#
#       HAI_Yam B/Texas/6/2011_d365  HAI_Yam B/Wisconsin/1/2010_d0  \
# 0                             NaN                       8.321928
# 1                             NaN                       6.321928
# 2                             NaN                       8.321928
# 3                             NaN                       5.321928
# 4                        5.321928                       6.321928
# ...                           ...                            ...
# 3752                          NaN                            NaN
# 3753                          NaN                            NaN
# 3754                          NaN                            NaN
# 3755                          NaN                            NaN
# 3756                          NaN                            NaN
#
#       HAI_Yam B/Wisconsin/1/2010_d28  HAI_Yam B/Wisconsin/1/2010_d365  \
# 0                           8.321928                              NaN
# 1                           6.321928                              NaN
# 2                           8.321928                              NaN
# 3                           6.321928                              NaN
# 4                           6.321928                         5.321928
# ...                              ...                              ...
# 3752                             NaN                              NaN
# 3753                             NaN                              NaN
# 3754                             NaN                              NaN
# 3755                             NaN                              NaN
# 3756                             NaN                              NaN
#
#       HAI_Yam B/Yamagata/16/1988_d0  HAI_Yam B/Yamagata/16/1988_d28  \
# 0                          7.321928                        8.321928
# 1                          5.321928                        5.321928
# 2                          8.321928                        8.321928
# 3                          3.321928                        5.321928
# 4                          5.321928                        5.321928
# ...                             ...                             ...
# 3752                            NaN                             NaN
# 3753                            NaN                             NaN
# 3754                            NaN                             NaN
# 3755                            NaN                             NaN
# 3756                            NaN                             NaN
#
#       HAI_Yam B/Yamagata/16/1988_d365
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                            5.321928
# ...                               ...
# 3752                              NaN
# 3753                              NaN
# 3754                              NaN
# 3755                              NaN
# 3756                              NaN
#
# [3757 rows x 196 columns]

# %%
# Save the cleaned dataset to the cleaned_data folder
os.makedirs('../cleaned_data', exist_ok=True)
df_pivot.to_csv('../cleaned_data/hai_cleaned.csv', index=False)
