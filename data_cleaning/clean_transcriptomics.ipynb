# %%
# Import required libraries
import os
import pandas as pd
from utils import log_standard_scale, peek
from pathlib import Path
RAW_DIR = Path("../data")

# %%
# Load the dataset
df = pd.read_csv('../data/train_transcriptomics_2019_UGA.tsv', sep='\t')
df
# Out:
#                                          transcriptomics_id   participant_id  \
# 0         BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# 1         BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# 2         BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# 3         BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# 4         BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# ...                                                     ...              ...
# 30523191  BS_RNA__2019_UGA.ID_477__2019_UGA_Standard_Flu...  2019_UGA.ID_477
# 30523192  BS_RNA__2019_UGA.ID_477__2019_UGA_Standard_Flu...  2019_UGA.ID_477
# 30523193  BS_RNA__2019_UGA.ID_477__2019_UGA_Standard_Flu...  2019_UGA.ID_477
# 30523194  BS_RNA__2019_UGA.ID_477__2019_UGA_Standard_Flu...  2019_UGA.ID_477
# 30523195  BS_RNA__2019_UGA.ID_477__2019_UGA_Standard_Flu...  2019_UGA.ID_477
#
#           timepoint  ensembl_gene_id  raw_count  tpm_count material
# 0                 0  ENSG00000000003        NaN   0.077926  Unknown
# 1                 0  ENSG00000000005        NaN   0.000000  Unknown
# 2                 0  ENSG00000000419        NaN   5.342548  Unknown
# 3                 0  ENSG00000000457        NaN   9.799336  Unknown
# 4                 0  ENSG00000000460        NaN   2.118530  Unknown
# ...             ...              ...        ...        ...      ...
# 30523191         28  ENSG00000284587        NaN   0.000000  Unknown
# 30523192         28  ENSG00000284594        NaN   0.000000  Unknown
# 30523193         28  ENSG00000284595        NaN   0.000000  Unknown
# 30523194         28  ENSG00000284596        NaN   0.000000  Unknown
# 30523195         28  ENSG00000284600        NaN   0.000000  Unknown
#
# [30523196 rows x 7 columns]

# %%
df = df.drop(columns=['transcriptomics_id'])
df.head()
# Out:
#     participant_id  timepoint  ensembl_gene_id  raw_count  tpm_count material
# 0  2019_UGA.ID_208          0  ENSG00000000003        NaN   0.077926  Unknown
# 1  2019_UGA.ID_208          0  ENSG00000000005        NaN   0.000000  Unknown
# 2  2019_UGA.ID_208          0  ENSG00000000419        NaN   5.342548  Unknown
# 3  2019_UGA.ID_208          0  ENSG00000000457        NaN   9.799336  Unknown
# 4  2019_UGA.ID_208          0  ENSG00000000460        NaN   2.118530  Unknown

# %%
# Drop raw_count (entirely NaN) and material (entirely 'Unknown') before pivoting
df = df.drop(columns=['raw_count', 'material'])
df.head()
# Out:
#     participant_id  timepoint  ensembl_gene_id  tpm_count
# 0  2019_UGA.ID_208          0  ENSG00000000003   0.077926
# 1  2019_UGA.ID_208          0  ENSG00000000005   0.000000
# 2  2019_UGA.ID_208          0  ENSG00000000419   5.342548
# 3  2019_UGA.ID_208          0  ENSG00000000457   9.799336
# 4  2019_UGA.ID_208          0  ENSG00000000460   2.118530

# %%
unique_genes_challenge = set(
    pd.read_csv(RAW_DIR / "challenge_transcriptomics.tsv", sep='\t')['ensembl_gene_id'].unique()
)
len(unique_genes_challenge)
# Out:
# 54902

# %%
df['timepoint'].unique()
# Out:
# array([ 0,  3,  7, 28])

# %%
# Filter to only timepoints 0, 7. Timepoint 3 not in the challenge set
df = df[df['timepoint'].isin([0, 7])]
# Filter to only challenge genes
df = df[df["ensembl_gene_id"].isin(unique_genes_challenge)]

# Pivot: each row is a (participant_id, timepoint), each gene becomes a column
df_pivot = df.pivot_table(
    index='participant_id',
    columns=['timepoint', 'ensembl_gene_id'],
    values='tpm_count'
)

# Flatten multi-level columns to "TRAN2019_{gene}_d{timepoint}" format
df_pivot.columns = [f'TRAN_{gene}_d{int(tp)}' for tp, gene in df_pivot.columns]
df_pivot = df_pivot.reset_index()

print(df_pivot.shape)
# Out:
# (275, 64125)

# %%
peek(df_pivot)
# Out:
#     participant_id  TRAN_ENSG00000000003_d0  TRAN_ENSG00000000005_d0  \
# 0  2019_UGA.ID_001                 0.149866                      0.0
# 1  2019_UGA.ID_005                 0.119232                      0.0
# 2  2019_UGA.ID_008                 0.096349                      0.0
# 3  2019_UGA.ID_011                 0.044666                      0.0
# 4  2019_UGA.ID_014                 0.000000                      0.0
#
#    TRAN_ENSG00000000419_d0  TRAN_ENSG00000000457_d0  TRAN_ENSG00000000460_d0  \
# 0                 8.066946                 8.457258                 3.973795
# 1                 3.209018                 7.973900                 2.521538
# 2                 5.277265                 7.289030                 1.913696
# 3                 3.733021                 8.731205                 3.491700
# 4                 5.207440                 9.466478                 2.931771
#
#    TRAN_ENSG00000000938_d0  TRAN_ENSG00000000971_d0  TRAN_ENSG00000001036_d0  \
# 0                95.386306                 0.034801                13.583601
# 1                83.430649                 0.110751                10.308613
# 2               138.440845                 0.143194                10.557651
# 3               150.812198                 0.074682                11.532723
# 4               129.608966                 0.128051                15.970298
#
#    TRAN_ENSG00000001084_d0  TRAN_ENSG00000001167_d0  TRAN_ENSG00000001460_d0  \
# 0                 7.965179                 7.187047                 1.590390
# 1                12.190398                 9.965058                 1.533703
# 2                14.385306                 5.401848                 1.982958
# 3                14.860079                11.703771                 1.149111
# 4                13.050625                10.539603                 1.994948
#
#    TRAN_ENSG00000001461_d0  TRAN_ENSG00000001497_d0  TRAN_ENSG00000001561_d0  \
# 0                13.973659                 9.685137                 3.203689
# 1                16.946756                10.774215                 6.274083
# 2                 9.914634                 6.998915                 2.006857
# 3                10.513365                 6.511664                10.136052
# 4                15.887030                 8.589723                10.012239
#
#    TRAN_ENSG00000001617_d0  TRAN_ENSG00000001626_d0  TRAN_ENSG00000001629_d0  \
# 0                 0.000000                      0.0                10.685926
# 1                 0.029305                      0.0                16.372074
# 2                 0.000000                      0.0                 4.988143
# 3                 0.000000                      0.0                15.577613
# 4                 0.112938                      0.0                14.760842
#
#    TRAN_ENSG00000001630_d0  TRAN_ENSG00000001631_d0
# 0                 3.141505                 8.707056
# 1                 2.892793                11.885934
# 2                 2.244099                 6.075266
# 3                 2.566189                12.220556
# 4                 3.121698                10.802686

# %%
df_pivot = log_standard_scale(df_pivot)
peek(df_pivot)
# Out:
#     participant_id  TRAN_ENSG00000000003_d0  TRAN_ENSG00000000005_d0  \
# 0  2019_UGA.ID_001                 1.001284                -0.123083
# 1  2019_UGA.ID_005                 0.586238                -0.123083
# 2  2019_UGA.ID_008                 0.268739                -0.123083
# 3  2019_UGA.ID_011                -0.473472                -0.123083
# 4  2019_UGA.ID_014                -1.145122                -0.123083
#
#    TRAN_ENSG00000000419_d0  TRAN_ENSG00000000457_d0  TRAN_ENSG00000000460_d0  \
# 0                 0.651376                 0.546033                 1.491505
# 1                -0.682261                 0.408613                 0.482631
# 2                 0.012367                 0.200666                -0.070990
# 3                -0.478352                 0.620830                 1.193616
# 4                -0.007073                 0.811627                 0.804596
#
#    TRAN_ENSG00000000938_d0  TRAN_ENSG00000000971_d0  TRAN_ENSG00000001036_d0  \
# 0                -0.622255                -1.007577                 0.598130
# 1                -0.929775                -0.492218                 0.042291
# 2                 0.235228                -0.282735                 0.089897
# 3                 0.432613                -0.732424                 0.266911
# 4                 0.083290                -0.379761                 0.929377
#
#    TRAN_ENSG00000001084_d0  TRAN_ENSG00000001167_d0  TRAN_ENSG00000001460_d0  \
# 0                 0.109457                 0.388386                 0.512635
# 1                 0.819701                 0.915067                 0.428503
# 2                 1.102819                -0.055020                 1.049170
# 3                 1.158720                 1.180399                -0.197465
# 4                 0.935906                 1.007133                 1.064422
#
#    TRAN_ENSG00000001461_d0  TRAN_ENSG00000001497_d0  TRAN_ENSG00000001561_d0  \
# 0                 1.018868                 0.923870                 0.007177
# 1                 1.455299                 1.194103                 0.816484
# 2                 0.256959                 0.117698                -0.487343
# 3                 0.385646                -0.057288                 1.445018
# 4                 1.308638                 0.622721                 1.428517
#
#    TRAN_ENSG00000001617_d0  TRAN_ENSG00000001626_d0  TRAN_ENSG00000001629_d0  \
# 0                -0.310983                -0.184023                 0.478017
# 1                 0.350294                -0.184023                 1.078850
# 2                -0.310983                -0.184023                -0.535201
# 3                -0.310983                -0.184023                 1.007912
# 4                 2.138805                -0.184023                 0.931346
#
#    TRAN_ENSG00000001630_d0  TRAN_ENSG00000001631_d0
# 0                 0.767752                 0.390241
# 1                 0.598956                 0.949021
# 2                 0.102128                -0.233563
# 3                 0.360122                 0.999589
# 4                 0.754686                 0.775816

# %%
df_pivot
# Out:
#       participant_id  TRAN_ENSG00000000003_d0  TRAN_ENSG00000000005_d0  \
# 0    2019_UGA.ID_001                 1.001284                -0.123083
# 1    2019_UGA.ID_005                 0.586238                -0.123083
# 2    2019_UGA.ID_008                 0.268739                -0.123083
# 3    2019_UGA.ID_011                -0.473472                -0.123083
# 4    2019_UGA.ID_014                -1.145122                -0.123083
# ..               ...                      ...                      ...
# 270  2019_UGA.ID_497                 1.554517                -0.123083
# 271  2019_UGA.ID_498                 0.254457                -0.123083
# 272  2019_UGA.ID_501                -0.771740                -0.123083
# 273  2019_UGA.ID_504                -0.418445                -0.123083
# 274  2019_UGA.ID_510                -0.020147                -0.123083
#
#      TRAN_ENSG00000000419_d0  TRAN_ENSG00000000457_d0  \
# 0                   0.651376                 0.546033
# 1                  -0.682261                 0.408613
# 2                   0.012367                 0.200666
# 3                  -0.478352                 0.620830
# 4                  -0.007073                 0.811627
# ..                       ...                      ...
# 270                -1.345502                 0.193105
# 271                -0.480561                -0.149424
# 272                 0.216741                 0.763328
# 273                -0.540762                 0.453294
# 274                -0.962808                -0.213974
#
#      TRAN_ENSG00000000460_d0  TRAN_ENSG00000000938_d0  \
# 0                   1.491505                -0.622255
# 1                   0.482631                -0.929775
# 2                  -0.070990                 0.235228
# 3                   1.193616                 0.432613
# 4                   0.804596                 0.083290
# ..                       ...                      ...
# 270                -0.319448                 0.425419
# 271                 0.664215                 0.655499
# 272                 0.711396                -0.286242
# 273                 0.277956                 0.012388
# 274                 0.278002                 1.059653
#
#      TRAN_ENSG00000000971_d0  TRAN_ENSG00000001036_d0  \
# 0                  -1.007577                 0.598130
# 1                  -0.492218                 0.042291
# 2                  -0.282735                 0.089897
# 3                  -0.732424                 0.266911
# 4                  -0.379761                 0.929377
# ..                       ...                      ...
# 270                -0.701448                -0.505792
# 271                -1.103482                -0.234756
# 272                 1.880704                 0.007824
# 273                -0.750934                -0.049752
# 274                -0.935225                 0.166960
#
#      TRAN_ENSG00000001084_d0  ...  TRAN_ENSG00000284479_d7  \
# 0                   0.109457  ...                -0.188175
# 1                   0.819701  ...                      NaN
# 2                   1.102819  ...                -0.188175
# 3                   1.158720  ...                -0.188175
# 4                   0.935906  ...                -0.188175
# ..                       ...  ...                      ...
# 270                -0.550410  ...                      NaN
# 271                -0.377774  ...                      NaN
# 272                -0.058472  ...                      NaN
# 273                 0.087081  ...                      NaN
# 274                -0.476082  ...                      NaN
#
#      TRAN_ENSG00000284484_d7  TRAN_ENSG00000284491_d7  \
# 0                  -0.685499                -0.078326
# 1                        NaN                      NaN
# 2                  -0.685499                -0.078326
# 3                   0.737034                -0.078326
# 4                  -0.685499                -0.078326
# ..                       ...                      ...
# 270                      NaN                      NaN
# 271                      NaN                      NaN
# 272                      NaN                      NaN
# 273                      NaN                      NaN
# 274                      NaN                      NaN
#
#      TRAN_ENSG00000284500_d7  TRAN_ENSG00000284513_d7  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ..                       ...                      ...
# 270                      NaN                      NaN
# 271                      NaN                      NaN
# 272                      NaN                      NaN
# 273                      NaN                      NaN
# 274                      NaN                      NaN
#
#      TRAN_ENSG00000284523_d7  TRAN_ENSG00000284526_d7  \
# 0                   0.769324                -0.481032
# 1                        NaN                      NaN
# 2                  -0.775653                -1.555837
# 3                   0.769319                 0.967365
# 4                  -0.775653                -1.298158
# ..                       ...                      ...
# 270                      NaN                      NaN
# 271                      NaN                      NaN
# 272                      NaN                      NaN
# 273                      NaN                      NaN
# 274                      NaN                      NaN
#
#      TRAN_ENSG00000284543_d7  TRAN_ENSG00000284546_d7  TRAN_ENSG00000284600_d7
# 0                  -1.943819                      NaN                 1.315984
# 1                        NaN                      NaN                      NaN
# 2                  -1.047953                      NaN                 1.315981
# 3                   0.743705                      NaN                -0.430140
# 4                  -0.152128                      NaN                -0.430140
# ..                       ...                      ...                      ...
# 270                      NaN                      NaN                      NaN
# 271                      NaN                      NaN                      NaN
# 272                      NaN                      NaN                      NaN
# 273                      NaN                      NaN                      NaN
# 274                      NaN                      NaN                      NaN
#
# [275 rows x 64125 columns]

# %%
# Save the cleaned dataset to the cleaned_data folder
os.makedirs('../cleaned_data', exist_ok=True)
df_pivot.to_parquet('../cleaned_data/transcriptomics_2019_UGA_cleaned.parquet', index=False)
