# %% [markdown]
# # Transcriptomics Data Cleaning — Training + Challenge
#
# **Processes all transcriptomics cohorts through a shared batch-correction and PCA pipeline, then saves train and challenge outputs separately.**
# - Input: `train_transcriptomics_2019_UGA.tsv`, `train_transcriptomics_2020_UGA.tsv`, `train_transcriptomics_SDY2867.tsv`, `challenge_transcriptomics.tsv`
# - Output: `transcriptomics_cleaned.csv`, `challenge_transcriptomics_cleaned.csv` (batch-corrected, PCA-reduced)

# %% [markdown]
# ## Design notes
#
# **Gene filtering:** Only genes present in the challenge set are retained, ensuring a consistent feature space across all cohorts.
#
# **Timepoints:** Day 0 only. Day 7 was considered but has too much missingness across cohorts.
#
# **Sparse column removal:** Genes missing in any participant (`MIN_PRESENT = 1.0`) are dropped before batch correction.
#
# **Batch correction:** pycombat corrects for four batch effects (2019_UGA, 2020_UGA, SDY2867, 2024_UGA) in log1p space.
#
# **PCA:** Fit on training participants only, then the challenge set is projected into the same PC space. `N_PCS = 290` retains ~96% of variance. `svd_solver='full'` is used because the data is wide (n_samples ≪ n_features).

# %%
MIN_PRESENT = 1  # drop gene columns with less than this fraction of non-NaN values
N_PCS = 290  # number of PCs to retain; covers ~96% variance (see scree plot)

# %%
DATA_PATH = '../data'
CLEAN_DATA_PATH = '../cleaned_data'

# %%
import os
import sys

sys.path.insert(0, '..')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from combat.pycombat import pycombat
from sklearn.decomposition import PCA

from data_cleaning.utils import peek

# %% [markdown]
# ## Load data

# %%
df_challenge = pd.read_csv(DATA_PATH + '/challenge_transcriptomics.tsv', sep='\t')
unique_genes_challenge = set(df_challenge['ensembl_gene_id'].unique())
print(f'Challenge genes: {len(unique_genes_challenge)}')
# Out:
# Challenge genes: 54902

# %%
df_2019_uga = pd.read_csv(DATA_PATH + '/train_transcriptomics_2019_UGA.tsv', sep='\t')
df_2020_uga = pd.read_csv(DATA_PATH + '/train_transcriptomics_2020_UGA.tsv', sep='\t')
df_sdy2867 = pd.read_csv(DATA_PATH + '/train_transcriptomics_SDY2867.tsv', sep='\t')

df_raw = pd.concat([df_2019_uga, df_2020_uga, df_sdy2867, df_challenge], axis=0).reset_index(drop=True)
print(f'Combined raw: {df_raw.shape}')
df_raw.head()
# Out:
# Combined raw: (60389504, 7)
#                                   transcriptomics_id   participant_id  \
# 0  BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# 1  BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# 2  BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# 3  BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
# 4  BS_RNA__2019_UGA.ID_208__2019_UGA_Standard_Flu...  2019_UGA.ID_208
#
#    timepoint  ensembl_gene_id  raw_count  tpm_count material
# 0          0  ENSG00000000003        NaN   0.077926  Unknown
# 1          0  ENSG00000000005        NaN   0.000000  Unknown
# 2          0  ENSG00000000419        NaN   5.342548  Unknown
# 3          0  ENSG00000000457        NaN   9.799336  Unknown
# 4          0  ENSG00000000460        NaN   2.118530  Unknown

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Filter genes and timepoints

# %%
df = df_raw.drop(columns=['transcriptomics_id', 'raw_count', 'material'])
df = df[df['timepoint'].isin([
    0
    # 7  # too much missingness
])]
df = df[df['ensembl_gene_id'].isin(unique_genes_challenge)]
print(f'After filtering: {df.shape}')
df.head()
# Out:
# After filtering: (16440274, 4)
#     participant_id  timepoint  ensembl_gene_id  tpm_count
# 0  2019_UGA.ID_208          0  ENSG00000000003   0.077926
# 1  2019_UGA.ID_208          0  ENSG00000000005   0.000000
# 2  2019_UGA.ID_208          0  ENSG00000000419   5.342548
# 3  2019_UGA.ID_208          0  ENSG00000000457   9.799336
# 4  2019_UGA.ID_208          0  ENSG00000000460   2.118530

# %% [markdown]
# ### Pivot to wide format

# %%
df_pivot = df.pivot_table(
    index='participant_id',
    columns=['timepoint', 'ensembl_gene_id'],
    values='tpm_count'
)
df_pivot.columns = [f'TRAN_{gene}_d{int(tp)}' for tp, gene in df_pivot.columns]
df_pivot = df_pivot.reset_index()
print(f'Pivoted shape: {df_pivot.shape}')
# Out:
# Pivoted shape: (435, 54903)

# %%
peek(df_pivot)
# Out:
#     participant_id  TRAN_ENSG00000000003_d0  TRAN_ENSG00000000005_d0  \
# 0  2019_UGA.ID_001                 0.149866                      0.0
# 1  2019_UGA.ID_005                 0.119232                      0.0
# 2  2019_UGA.ID_008                 0.096349                      0.0
# 3  2019_UGA.ID_011                 0.044666                      0.0
# 4  2019_UGA.ID_014                 0.000000                      0.0
#
#    TRAN_ENSG00000000419_d0  TRAN_ENSG00000000457_d0  TRAN_ENSG00000000460_d0  \
# 0                 8.066946                 8.457258                 3.973795
# 1                 3.209018                 7.973900                 2.521538
# 2                 5.277265                 7.289030                 1.913696
# 3                 3.733021                 8.731205                 3.491700
# 4                 5.207440                 9.466478                 2.931771
#
#    TRAN_ENSG00000000938_d0  TRAN_ENSG00000000971_d0  TRAN_ENSG00000001036_d0  \
# 0                95.386306                 0.034801                13.583601
# 1                83.430649                 0.110751                10.308613
# 2               138.440845                 0.143194                10.557651
# 3               150.812198                 0.074682                11.532723
# 4               129.608966                 0.128051                15.970298
#
#    TRAN_ENSG00000001084_d0  TRAN_ENSG00000001167_d0  TRAN_ENSG00000001460_d0  \
# 0                 7.965179                 7.187047                 1.590390
# 1                12.190398                 9.965058                 1.533703
# 2                14.385306                 5.401848                 1.982958
# 3                14.860079                11.703771                 1.149111
# 4                13.050625                10.539603                 1.994948
#
#    TRAN_ENSG00000001461_d0  TRAN_ENSG00000001497_d0  TRAN_ENSG00000001561_d0  \
# 0                13.973659                 9.685137                 3.203689
# 1                16.946756                10.774215                 6.274083
# 2                 9.914634                 6.998915                 2.006857
# 3                10.513365                 6.511664                10.136052
# 4                15.887030                 8.589723                10.012239
#
#    TRAN_ENSG00000001617_d0  TRAN_ENSG00000001626_d0  TRAN_ENSG00000001629_d0  \
# 0                 0.000000                      0.0                10.685926
# 1                 0.029305                      0.0                16.372074
# 2                 0.000000                      0.0                 4.988143
# 3                 0.000000                      0.0                15.577613
# 4                 0.112938                      0.0                14.760842
#
#    TRAN_ENSG00000001630_d0  TRAN_ENSG00000001631_d0
# 0                 3.141505                 8.707056
# 1                 2.892793                11.885934
# 2                 2.244099                 6.075266
# 3                 2.566189                12.220556
# 4                 3.121698                10.802686

# %% [markdown]
# ### Drop sparse gene columns

# %%
gene_cols = [c for c in df_pivot.columns if c != 'participant_id']
present_frac = df_pivot[gene_cols].notna().mean()
sparse_cols = present_frac[present_frac < MIN_PRESENT].index.tolist()
df_pivot = df_pivot.drop(columns=sparse_cols)
print(f'Dropped {len(sparse_cols)} columns with <{MIN_PRESENT:.0%} present values.')
print(f'Shape after dropping: {df_pivot.shape}')
# Out:
# Dropped 24080 columns with <100% present values.
# Shape after dropping: (435, 30823)

# %%
d0_genes = {c.replace('_d0', '') for c in df_pivot.columns if c.endswith('_d0')}
d7_genes = {c.replace('_d7', '') for c in df_pivot.columns if c.endswith('_d7')}
missing_d7 = d0_genes - d7_genes
print(f'd0 cols: {len(d0_genes)}, d7 cols: {len(d7_genes)}')
print(f'Genes with d0 but no d7: {len(missing_d7)}')
# Out:
# d0 cols: 30822, d7 cols: 0
# Genes with d0 but no d7: 30822

# %% [markdown]
# ## Batch correction

# %%
gene_cols = [c for c in df_pivot.columns if c != 'participant_id']

participants_2019_uga = set(df_2019_uga['participant_id'].unique())
participants_2020_uga = set(df_2020_uga['participant_id'].unique())
participants_sdy2867 = set(df_sdy2867['participant_id'].unique())
participants_challenge = set(df_challenge['participant_id'].unique())


def get_batch(pid):
    if pid in participants_2019_uga:
        return '2019_UGA'
    elif pid in participants_2020_uga:
        return '2020_UGA'
    elif pid in participants_sdy2867:
        return 'SDY2867'
    else:
        return '2024_UGA'


batch = df_pivot['participant_id'].map(get_batch).tolist()
print('Batch counts:', pd.Series(batch).value_counts().to_dict())
# Out:
# Batch counts: {'2019_UGA': 275, 'SDY2867': 72, '2020_UGA': 48, '2024_UGA': 40}

# %%
# pycombat expects genes x samples DataFrame in log scale
expr_df = pd.DataFrame(
    np.log1p(df_pivot[gene_cols].values).T,
    index=gene_cols,
    columns=df_pivot['participant_id']
)
corrected_df = pycombat(expr_df, batch)

df_pivot[gene_cols] = corrected_df.values.T
print('Batch correction done. Shape:', df_pivot.shape)
peek(df_pivot)
# Out:
# Found 4 batches.
# Adjusting for 0 covariate(s) or covariate level(s).
# Standardizing Data across genes.
# Fitting L/S model and finding priors.
# Finding parametric adjustments.
# /Users/chayan/anaconda3/envs/cmi-flu-prediction-challenge-capstone/lib/python3.13/site-packages/combat/pycombat.py:159: RuntimeWarning: divide by zero encountered in divide
#   np.absolute(d_new-d_old)/d_old))  # maximum difference between new and old estimate
# Adjusting the Data
# Batch correction done. Shape: (435, 30823)
#     participant_id  TRAN_ENSG00000000003_d0  TRAN_ENSG00000000005_d0  \
# 0  2019_UGA.ID_001                 0.217676                 0.000681
# 1  2019_UGA.ID_005                 0.178297                 0.000681
# 2  2019_UGA.ID_008                 0.148174                 0.000681
# 3  2019_UGA.ID_011                 0.077755                 0.000681
# 4  2019_UGA.ID_014                 0.014031                 0.000681
#
#    TRAN_ENSG00000000419_d0  TRAN_ENSG00000000457_d0  TRAN_ENSG00000000460_d0  \
# 0                 2.700943                 2.193857                 1.538282
# 1                 2.142656                 2.150939                 1.248649
# 2                 2.433441                 2.085995                 1.089712
# 3                 2.228017                 2.217217                 1.452762
# 4                 2.425303                 2.276805                 1.341080
#
#    TRAN_ENSG00000000938_d0  TRAN_ENSG00000000971_d0  TRAN_ENSG00000001036_d0  \
# 0                 5.014220                 0.374041                 2.917761
# 1                 4.903687                 0.453118                 2.690169
# 2                 5.322429                 0.485261                 2.709662
# 3                 5.393376                 0.416261                 2.782141
# 4                 5.267817                 0.470374                 3.053391
#
#    TRAN_ENSG00000001084_d0  TRAN_ENSG00000001167_d0  TRAN_ENSG00000001460_d0  \
# 0                 2.332826                 2.480567                 0.880844
# 1                 2.665814                 2.721275                 0.863687
# 2                 2.798550                 2.277917                 0.990256
# 3                 2.824759                 2.842540                 0.736037
# 4                 2.720295                 2.763352                 0.993367
#
#    TRAN_ENSG00000001461_d0  TRAN_ENSG00000001497_d0  TRAN_ENSG00000001561_d0  \
# 0                 2.733046                 2.578877                 1.636570
# 1                 2.892106                 2.664688                 2.106086
# 2                 2.455363                 2.322883                 1.349678
# 3                 2.502264                 2.267317                 2.470727
# 4                 2.838654                 2.483249                 2.461154
#
#    TRAN_ENSG00000001617_d0  TRAN_ENSG00000001626_d0  TRAN_ENSG00000001629_d0  \
# 0                 0.016114                -0.000278                 2.587809
# 1                 0.069490                -0.000278                 2.919791
# 2                 0.016114                -0.000278                 2.027971
# 3                 0.016114                -0.000278                 2.880595
# 4                 0.213850                -0.000278                 2.838290
#
#    TRAN_ENSG00000001630_d0  TRAN_ENSG00000001631_d0
# 0                 1.585122                 2.224601
# 1                 1.529944                 2.447571
# 2                 1.367534                 1.975684
# 3                 1.451871                 2.467749
# 4                 1.580851                 2.378457

# %%
batch_series = pd.Series(batch)
unique_batches = batch_series.unique()
colors = plt.cm.tab10.colors

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

for ax, data, title in zip(
        axes,
        [expr_df.T, corrected_df.T],
        ['Before batch correction', 'After batch correction']
):
    pca = PCA(n_components=2)
    coords = pca.fit_transform(data.values)
    for i, b in enumerate(unique_batches):
        mask = (batch_series == b).values
        ax.scatter(coords[mask, 0], coords[mask, 1], label=b, alpha=0.7, s=15, color=colors[i])
    ax.set_title(title)
    ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%})')
    ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%})')
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## PCA dimensionality reduction

# %% [markdown]
# ### Scree plot

# %%
# svd_solver='full' is correct for wide data (n_samples=435 << n_features=30k)
pca_full = PCA(svd_solver='full', n_components=min(435, len(gene_cols)))
pca_full.fit(corrected_df.values.T)  # samples x genes

cumvar = np.cumsum(pca_full.explained_variance_ratio_)
n_components = np.arange(1, len(cumvar) + 1)

thresholds = [0.70, 0.75, 0.80, 0.90, 0.95]
n_for_threshold = {t: np.searchsorted(cumvar, t) + 1 for t in thresholds}
for t, n in n_for_threshold.items():
    print(f'{t:.0%} variance explained by {n} PCs')

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

axes[0].plot(n_components, cumvar, linewidth=1)
for t in thresholds:
    n = n_for_threshold[t]
    axes[0].axhline(t, color='grey', linestyle='--', linewidth=0.8)
    axes[0].axvline(n, color='grey', linestyle='--', linewidth=0.8)
    axes[0].text(n + 3, t - 0.015, f'{t:.0%} ({n} PCs)', fontsize=8)
axes[0].set_xlabel('Number of PCs')
axes[0].set_ylabel('Cumulative explained variance')
axes[0].set_title('Scree plot (all components)')

axes[1].plot(n_components[:100], cumvar[:100], linewidth=1)
for t in thresholds:
    n = n_for_threshold[t]
    if n <= 100:
        axes[1].axhline(t, color='grey', linestyle='--', linewidth=0.8)
        axes[1].axvline(n, color='grey', linestyle='--', linewidth=0.8)
        axes[1].text(n + 1, t - 0.015, f'{t:.0%} ({n} PCs)', fontsize=8)
axes[1].set_xlabel('Number of PCs')
axes[1].set_ylabel('Cumulative explained variance')
axes[1].set_title('Scree plot (first 100 components)')

plt.tight_layout()
plt.show()
# Out:
# 70% variance explained by 28 PCs
# 75% variance explained by 48 PCs
# 80% variance explained by 84 PCs
# 90% variance explained by 202 PCs
# 95% variance explained by 290 PCs

# %% [markdown]
# ### Fit on training, transform challenge

# %%
train_pids = df_pivot[df_pivot['participant_id'].isin(
    participants_2019_uga | participants_2020_uga | participants_sdy2867
)]['participant_id'].values
challenge_pids = df_pivot[df_pivot['participant_id'].isin(
    participants_challenge
)]['participant_id'].values

train_corrected = corrected_df[train_pids].T  # 395 x genes
challenge_corrected = corrected_df[challenge_pids].T  # 40  x genes

# svd_solver='full': LAPACK thin SVD, correct for wide data (395 samples << 30k genes)
# randomized only helps when n_components << n_samples; 290/395=73% is too high to benefit
pca_final = PCA(n_components=N_PCS, svd_solver='full')
train_pcs = pca_final.fit_transform(train_corrected)
challenge_pcs = pca_final.transform(challenge_corrected)

pc_cols = [f'TRAN_PC{i + 1}' for i in range(N_PCS)]

df_train_pca = pd.DataFrame(train_pcs, columns=pc_cols)
df_train_pca.insert(0, 'participant_id', train_pids)

df_challenge_pca = pd.DataFrame(challenge_pcs, columns=pc_cols)
df_challenge_pca.insert(0, 'participant_id', challenge_pids)

print(f'Train PCA shape:     {df_train_pca.shape}')
print(f'Challenge PCA shape: {df_challenge_pca.shape}')
print(f'Variance explained by {N_PCS} PCs: {pca_final.explained_variance_ratio_.sum():.1%}')
# Out:
# Train PCA shape:     (395, 291)
# Challenge PCA shape: (40, 291)
# Variance explained by 290 PCs: 96.3%

# %%
os.makedirs(CLEAN_DATA_PATH, exist_ok=True)

df_train_pca.to_csv(CLEAN_DATA_PATH + '/transcriptomics_cleaned.csv', index=False)
df_challenge_pca.to_csv(CLEAN_DATA_PATH + '/challenge_transcriptomics_cleaned.csv', index=False)

print(f'Saved train PCA:     {CLEAN_DATA_PATH}/transcriptomics_cleaned.csv')
print(f'Saved challenge PCA: {CLEAN_DATA_PATH}/challenge_transcriptomics_cleaned.csv')
# Out:
# Saved train PCA:     ../cleaned_data/transcriptomics_cleaned.csv
# Saved challenge PCA: ../cleaned_data/challenge_transcriptomics_cleaned.csv
