# %% [markdown]
# # Merge Submissions
# This notebook finds all individual task CSVs in the current folder and merges them into a single `final_submission.csv`.

# %%
import os
import glob
import re
import pandas as pd
from functools import reduce

# %%
# Find all task CSVs in the current (submission) directory
csv_files = glob.glob('task_*.csv')
print(f"Found {len(csv_files)} files to merge: {csv_files}\n")

if csv_files:
    # Read each CSV into a list of DataFrames
    dfs = [pd.read_csv(f) for f in csv_files]
    
    # Merge all DataFrames dynamically on 'Participant_ID' using an outer join
    final_df = reduce(lambda left, right: pd.merge(left, right, on='Participant_ID', how='outer'), dfs)
    
    # Sort columns: Participant_ID first, then numerically by task number
    def sort_cols(col_name):
        if col_name == 'Participant_ID':
            return -1
        match = re.search(r'4\.(\d+)', col_name)
        return int(match.group(1)) if match else 999
        
    final_df = final_df[sorted(final_df.columns, key=sort_cols)]
    
    # Export to final_submission.csv
    final_df.to_csv('final_submission.csv', index=False)
    print("Successfully saved merged data to 'final_submission.csv'!")
    display(final_df)
else:
    print("No 'task_*.csv' files found in the current directory.")
# Out:
# Found 8 files to merge: ['task_4_10.csv', 'task_4_2.csv', 'task_4_3.csv', 'task_4_4.csv', 'task_4_5.csv', 'task_4_6.csv', 'task_4_8.csv', 'task_4_9.csv']
#
# Successfully saved merged data to 'final_submission.csv'!
#         Participant_ID  Task_4.10  Task_4.2  Task_4.3  Task_4.4*   Task_4.5*  \
# 0      2016_UGA.ID_001        NaN       NaN       NaN        NaN  111.052051
# 1      2016_UGA.ID_002        NaN       NaN       NaN        NaN  114.021216
# 2      2016_UGA.ID_003        NaN       NaN       NaN        NaN   67.712790
# 3      2016_UGA.ID_004        NaN       NaN       NaN        NaN   50.420341
# 4      2016_UGA.ID_005        NaN       NaN       NaN        NaN   58.961596
# ...                ...        ...       ...       ...        ...         ...
# 3673  SDY887.SUB134259        NaN       NaN       NaN        NaN   46.131922
# 3674  SDY887.SUB134260        NaN       NaN       NaN        NaN   53.075671
# 3675  SDY887.SUB197783        NaN       NaN       NaN        NaN   19.585965
# 3676  SDY887.SUB197784        NaN       NaN       NaN        NaN   41.711137
# 3677  SDY887.SUB197785        NaN       NaN       NaN        NaN   21.136753
#
#       Task_4.6  Task_4.8  Task_4.9
# 0     0.825830       NaN       NaN
# 1     0.802030       NaN       NaN
# 2     0.674154       NaN       NaN
# 3     0.589003       NaN       NaN
# 4     0.587596       NaN       NaN
# ...        ...       ...       ...
# 3673  0.537738       NaN       NaN
# 3674  0.521246       NaN       NaN
# 3675  0.286129       NaN       NaN
# 3676  0.548640       NaN       NaN
# 3677  0.295906       NaN       NaN
#
# [3678 rows x 9 columns]
